# %%
from simulation import Simulation

import random
import numpy as np
import matplotlib.pyplot as plt
import pathlib
# Important for animation to run inline
# %matplotlib ipympl

# %%
path = pathlib.Path().resolve()
proj_dir = str(path.parent.parent.parent)
save_folder = proj_dir + '\\DS-AI\\data\\processed_data\\normalized_training_data'
sim = [0,203]
number_grids = 64

# %%
display(save_folder)
# Out:
# 'C:\\Users\\sagi8\\Documents\\GitHub\\DS-AI\\data\\processed_data\\normalized_training_data'

# %%
test_sim = []
for i in range(len(sim)):
    coords = np.loadtxt(f"{save_folder}\\DEM\\dem_tra_norm{sim[i]}")[:, 2].reshape(number_grids,number_grids)
    topo = np.loadtxt(f"{save_folder}\\DEM\\dem_tra_norm{sim[i]}")[:, 2].reshape(number_grids,number_grids)
    wd = np.loadtxt(f"{save_folder}\\WD\\wd_tra_norm{sim[i]}").reshape(-1,number_grids,number_grids)
    vx = np.loadtxt(f"{save_folder}\\VX\\vx_tra_norm{sim[i]}").reshape(-1,number_grids,number_grids)
    vy = np.loadtxt(f"{save_folder}\\vy\\vy_tra_norm{sim[i]}").reshape(-1,number_grids,number_grids)
    test_sim.append(Simulation(coords, topo, wd, vx, vy))

# %%
# Test animation
for i in range(len(sim)):
    ani = test_sim[i].plot_animation()
# Out:
# c:\Users\sagi8\anaconda3\envs\dsaie\lib\site-packages\matplotlib\animation.py:887: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for i in range(len(sim)):
    fig = test_sim[i].plot_vector(-1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
