# %%
import sys
import pathlib

import numpy as np
from simulation import Simulation
from watertopo import WaterTopo

# Local
cwd = pathlib.Path().resolve()
src = cwd.parent
root = src.parent
sys.path.append(str(src))

# Important for simulation to run inline
# %matplotlib ipympl

# %%
number_grids = 64
save_folder = str(root)+"/data/normalized_data/tra_val"

test_sim = WaterTopo.load_simulations(save_folder, 10, number_grids, use_augmented=False, random_state=42)
# Out:
# ['DEM_10_o.txt', 'DEM_11_o.txt', 'DEM_12_o.txt', 'DEM_13_o.txt', 'DEM_14_o.txt', 'DEM_15_o.txt', 'DEM_16_o.txt', 'DEM_17_o.txt', 'DEM_18_o.txt', 'DEM_19_o.txt', 'DEM_1_o.txt', 'DEM_20_o.txt', 'DEM_21_o.txt', 'DEM_22_o.txt', 'DEM_23_o.txt', 'DEM_24_o.txt', 'DEM_25_o.txt', 'DEM_26_o.txt', 'DEM_27_o.txt', 'DEM_28_o.txt', 'DEM_29_o.txt', 'DEM_2_o.txt', 'DEM_30_o.txt', 'DEM_31_o.txt', 'DEM_32_o.txt', 'DEM_33_o.txt', 'DEM_34_o.txt', 'DEM_35_o.txt', 'DEM_36_o.txt', 'DEM_37_o.txt', 'DEM_38_o.txt', 'DEM_39_o.txt', 'DEM_3_o.txt', 'DEM_40_o.txt', 'DEM_41_o.txt', 'DEM_42_o.txt', 'DEM_43_o.txt', 'DEM_44_o.txt', 'DEM_45_o.txt', 'DEM_46_o.txt', 'DEM_47_o.txt', 'DEM_48_o.txt', 'DEM_49_o.txt', 'DEM_4_o.txt', 'DEM_50_o.txt', 'DEM_51_o.txt', 'DEM_52_o.txt', 'DEM_53_o.txt', 'DEM_54_o.txt', 'DEM_55_o.txt', 'DEM_56_o.txt', 'DEM_57_o.txt', 'DEM_58_o.txt', 'DEM_59_o.txt', 'DEM_5_o.txt', 'DEM_60_o.txt', 'DEM_61_o.txt', 'DEM_62_o.txt', 'DEM_63_o.txt', 'DEM_64_o.txt', 'DEM_65_o.txt', 'DEM_66_o.txt', 'DEM_67_o.txt', 'DEM_68_o.txt', 'DEM_69_o.txt', 'DEM_6_o.txt', 'DEM_70_o.txt', 'DEM_71_o.txt', 'DEM_72_o.txt', 'DEM_73_o.txt', 'DEM_74_o.txt', 'DEM_75_o.txt', 'DEM_76_o.txt', 'DEM_77_o.txt', 'DEM_78_o.txt', 'DEM_79_o.txt', 'DEM_7_o.txt', 'DEM_80_o.txt', 'DEM_8_o.txt', 'DEM_9_o.txt']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 number_grids = 64
#       2 save_folder = str(root)+"/data/normalized_data/tra_val"
# ----> 4 test_sim = WaterTopo.load_simulations(save_folder, 81, number_grids, use_augmented=False, random_state=42)
#
# File c:\Users\pjdeb\OneDrive\Documenten\Universiteit\CT 5\Q2\Unit 3\DS-AI\src\utils\watertopo.py:40, in WaterTopo.load_simulations(save_folder, sim_amount, number_grids, use_augmented, random_state)
#      36     name_dict = {"DEM":"dem",
#      37                  "WD": "wd"}
#      39 if sim_amount > len(fnames):
# ---> 40     raise Exception(f"Please select an amount smaller than {len(fnames)}.")
#      42 np.random.seed(random_state)
#      43 idx = random.sample(range(len(fnames)), sim_amount)
#
# Exception: Please select an amount smaller than 80.

# %%
# Manual load example:
coords = np.loadtxt(f"{save_folder}\\DEM\\DEM_{sim}.txt")[:, :2].reshape(number_grids,number_grids)
topo = np.loadtxt(f"{save_folder}\\DEM\\DEM_{sim}.txt")[:, 2].reshape(number_grids,number_grids)
wd = np.loadtxt(f"{save_folder}\\WD\\WD_{sim}.txt").reshape(-1,number_grids,number_grids)
vx = np.loadtxt(f"{save_folder}\\VX\\VX_{sim}.txt").reshape(-1,number_grids,number_grids)
vy = np.loadtxt(f"{save_folder}\\vy\\vy_{sim}.txt").reshape(-1,number_grids,number_grids)

test_sim = Simulation(coords, topo, wd, vx, vy)

# %%
# Test animation
ani = test_sim.plot_animation()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Test vector plot
fig = test_sim.plot_vector(-1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
