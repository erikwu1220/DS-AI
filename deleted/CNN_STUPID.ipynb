# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

from simulation import Simulation

# %%
test_sim = Simulation.load_simulation("..\\data\\processed_data\\normalized_training_data", 10, 64)
test_sim = Simulation.load_simulation("..\\data\\augmented_data", 10, 64)

# %%
# Load training data
num_sims = 10

sims = Simulation.load_simulations("..\\data\\processed_data\\normalized_training_data", 10, 64)
data = sims[1].return_timestep(50)

fig, axs = plt.subplots(1,3)

for i, ax in enumerate(axs):
    ax.imshow(data[i])

print(np.sum(data[0] - data[2]))

sims = Simulation.load_simulations("..\\data\\augmented_data", 10, 64)
# Out:
# 0.0
